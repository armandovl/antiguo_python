# %%
# %matplotlib inline 
import pandas as pd #importamos Pandas
#df = pd.read_excel('Datos_Rosa_de_Vientos.xlsx') 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Base_de_Datos= pd.read_excel('Para Ejercicios.xlsx')

# %%
Datos=pd.DataFrame(Base_de_Datos)
#lo convertimos en un data frame

# %%
Datos
# Out:
#      Edad  Genero  Escolaridad  Experiencia  Numero_Vientres  \
# 0      67  Hombre            9           45                7
# 1      25  Hombre           12            6               11
# 2      35   Mujer            9           49               30
# 3      15  Hombre            9            4               25
# 4      34   Mujer            9            4                2
# 5      37  Hombre            9           49               30
# 6      34  Hombre            9            4               20
# 7      30  Hombre            9            4                0
# 8      61  Hombre            9            4                8
# 9      43   Mujer            9            5                0
# 10     54   Mujer            5            4                1
# 11     57   Mujer            2            4                3
# 12     62  Hombre           16            5                9
# 13     49   Mujer            2           33                3
# ...

# %%
sns.set(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")



# Plot the orbital period with horizontal boxes
sns.boxplot(x="Edad", y="Municipio", data=Datos,
            whis="range", palette="vlag")

# Add in points to show each observation
sns.swarmplot(x="Edad", y="Municipio", data=Datos,
              size=2, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)

# %%
Base2= pd.read_excel('tips.xlsx')
Datos2=pd.DataFrame(Base2)
#lo convertimos en un data frame

# %%
sns.set(style="darkgrid")
g = sns.jointplot("total_bill", "tip", data=Datos2, kind="reg",
                  xlim=(0, 60), ylim=(0, 12), color="m")

# %%
sns.set(style="darkgrid")
g = sns.jointplot("Escolaridad", "Experiencia", data=Datos, kind="reg",
                  xlim=(0, 16), ylim=(0, 60), color="m")

# %%
sns.set(style="whitegrid")

ax=sns.stripplot(
              x="Genero",
              hue="Municipio",
              y="Edad",
              data=Datos)
#boxenplot cambio por lvplot
ax=sns.lvplot(
              x="Genero",
              hue="Municipio",
              y="Edad",
              data=Datos)

# %%
import seaborn as sns
sns.set()

# Load the iris dataset
iris = sns.load_dataset("iris")

# Plot sepal with as a function of sepal_length across days
g = sns.lmplot(x="sepal_length", y="sepal_width", hue="species",
               truncate=True, height=5, data=iris)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Sepal length (mm)", "Sepal width (mm)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-db9badc081fe> in <module>()
#       7 # Plot sepal with as a function of sepal_length across days
#       8 g = sns.lmplot(x="sepal_length", y="sepal_width", hue="species",
# ----> 9                truncate=True, height=5, data=iris)
#      10
#      11 # Use more informative axis labels than are provided by default
#
# TypeError: lmplot() got an unexpected keyword argument 'height'
