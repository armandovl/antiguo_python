# %%
#importante para que se ejecuten los gráficos
# %matplotlib inline
import pandas as pd #importamos Pandas
import matplotlib.pyplot as plt #importamos matplotlib
import seaborn as sns #importamos seaborn

# %%
Leer_excel= pd.read_excel('paredes.xlsx')

# %%
Datos=pd.DataFrame(Leer_excel)#lo convertimos en un data frame

# %%
Datos.head()

# %%
ax=sns.lvplot(y="cNTotal",x="rProceso",data=Datos, palette="Set3")
ax =sns.stripplot(y="cNTotal",x="rProceso", data=Datos, size=1, jitter=True, color="gray")

# %%
plt.figure(figsize=(20,10))
sns.boxplot(
    data=Datos,
    x='rProceso',
    y='cNTotal',
    color='red')

# %%
vv=sns.swarmplot(x="rProceso", y="cNTotal", data=Datos)

# %%
sns.lvplot(x=Datos["cNTotal"])

# %%
sns.lvplot(x=Datos["Edad"])

# %%
sns.lvplot(x=Datos["InAI"])

# %%
sns.lvplot(x=Datos["Cercania_Fuera"])

# %%
ax=sns.lvplot(x="Genero", y="Edad", data=Datos)

# %%
ax=sns.lvplot(x="Municipio", y="Edad", data=Datos,)

# %%
sns.lvplot(x="Percepcion", y="Edad", data=Datos)

# %%
sns.lvplot(x="Genero", y="Edad", hue="Percepcion",data=Datos, palette="Set3")

# %%
ax=sns.lvplot(x="Genero", y="Edad",data=Datos, palette="Set3")
ax =sns.stripplot(x="Genero", y="Edad", data=Datos, size=4, jitter=True, color="gray")

# %%
ax=sns.lvplot(x="Edad", y="Genero",data=Datos, palette="Set3",orient="h")

# %%
sns.lvplot(x="Edad", y="Genero", hue="Percepcion",data=Datos, palette="Set3",orient="h")

# %%
# factorplot en lugar de cat plot
#https://seaborn.pydata.org/whatsnew.html
g = sns.factorplot(x="Genero", y="Edad", capsize=.2, palette="YlGnBu_d", height=6, aspect=.75,
                kind="point", data=Datos)
g.despine(left=True)

# %%
# factorplot en lugar de cat plot
#https://seaborn.pydata.org/whatsnew.html
g = sns.factorplot(x="Municipio", y="Edad",capsize=.2, palette="YlGnBu_d", height=10, aspect=2.5,
                kind="point", data=Datos)
g.despine(left=True)

# %%
# factorplot en lugar de cat plot
#https://seaborn.pydata.org/whatsnew.html
g = sns.factorplot(x="Municipio", y="Edad",col="Genero", capsize=.2, palette="YlGnBu_d", height=20, aspect=2,
                kind="point", data=Datos)
g.despine(left=True)
