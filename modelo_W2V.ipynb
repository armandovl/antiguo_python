# %% [markdown]
# # Crear un modelo de Word2Vec
#
# Este ejemplo esta disponible con extencion
# - __.py__ para ser cargado desde cualquier IDE (Pychar, Spyder, etc)
# - __.ipynb__ para notebook
#
# Requerimientos:
# - NLTK: Installar ejecutar el comando __pip install nltk__
# - Gensim: Instalar con __pip install gensim__

# %%
#!pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\armando\anaconda3\lib\site-packages
# Requirement already satisfied: thinc==7.4.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: setuptools in c:\users\armando\anaconda3\lib\site-packages\setuptools-27.2.0-py3.6.egg (from spacy)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\armando\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy)
# Requirement already satisfied: zipp>=0.5 in c:\users\armando\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy)
# You are using pip version 9.0.1, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
#importamos otra libreria importante para tokenizar en oraciones
import spacy

# %%
# !python -m spacy download es_core_news_sm
# Out:
# Requirement already satisfied: es_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.2.5/es_core_news_sm-2.2.5.tar.gz#egg=es_core_news_sm==2.2.5 in c:\users\armando\anaconda3\lib\site-packages
# Requirement already satisfied: spacy>=2.2.2 in c:\users\armando\anaconda3\lib\site-packages (from es_core_news_sm==2.2.5)
# Requirement already satisfied: thinc==7.4.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: setuptools in c:\users\armando\anaconda3\lib\site-packages\setuptools-27.2.0-py3.6.egg (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\armando\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\armando\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\armando\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\armando\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5)
# [+] Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# You are using pip version 9.0.1, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
#cargamos la biblioteca en español
nlp= spacy.load('es_core_news_sm')
#en este punto se tiene que reiniciar todo y ejecutar de nuevo

# %%
import nltk
import gensim

# %%
#Descomenta las dos siguientes lineas si no tienes instalado nltk y/o gensim
#! pip install nltk 
#! pip install gensim

# %% [markdown]
# # Leer Corpus

# %%
with open ('orasi.txt',
           'r',encoding='utf-8') as file:
        document = file.read()

# %%
doc = nlp(document) #aplicamos la bibliotea a mi texto

# %%
#Para tokenizar oraciones
oraciones_lista = []
separator = ','
doc=nlp(document)
for num,oracion in enumerate(doc.sents):
    #print(f'{num}: {oracion}')
    oraciones_lista.append(oracion)

# %%
#4# mio
#Funcion Tokenizar
def tokenizar(texto_para_tonekizar):
  from nltk.tokenize import word_tokenize #importar la parte tokenizadora
  salida_funcion_tok = word_tokenize(texto_para_tonekizar,"spanish") #secciona o tokeniza
  salida_funcion_tok =[word.lower() for word in salida_funcion_tok if word.isalpha()] # Remover los signos de puntuación
  return(salida_funcion_tok)

# %%
#mio tokenizar palabras 
texto_tokenizado=tokenizar(document)

# %%
texto_tokenizado
# Out:
# ['producto',
#  'llegó',
#  'responden',
#  'correos',
#  'peor',
#  'contestan',
#  'correos',
#  'mando',
#  'compren',
#  'recomiendo',
#  'puede',
#  'devolver',
#  'ser',
#  'producto',
#  'alimenticio',
#  'general',
#  'mala',
#  'experiencia',
#  'cafe',
#  've',
#  'fecha',
#  'lote',
#  'ningun',
#  'lado',
#  'cobraron',
#  'pesos',
#  'producto',
#  'llegó',
#  'demasiado',
#  'molesta',
#  'mandaron',
#  'paquete',
#  'caduca',
#  'noviembre',
#  'osea',
#  'prácticamente',
#  'falta',
#  'mes',
#  'mal',
#  'vuelvo',
#  'comprar',
#  'hice',
#  'reclamación',
#  'enviaron',
#  'frasco',
#  'repuesto',
#  'muele',
#  'perfectamente',
#  'máquina',
#  'filtro',
#  'goteo',
#  'puede',
#  'ser',
#  'totalmente',
#  'adecuado',
#  'lastima',
#  'pueda',
#  'además',
#  'compré',
#  'perdió',
#  'devolución',
#  'intento',
#  'llegó',
#  'mal',
#  'etiqueta',
#  'sobrepuesta',
#  'cumplió',
#  'descrito',
#  'recomiendo',
#  'comprar',
#  'café',
#  'directamente',
#  'tienda',
#  'internet',
#  'así',
#  'sabe',
#  'compra',
#  'amazon',
#  'permiten',
#  'devoluciones',
#  'aunque',
#  'pague',
#  'membresía',
#  'llego',
#  'pedi',
#  'reembolso',
#  'preparado',
#  'pour',
#  'over',
#  'bodum',
#  'cafetera',
#  'goteo',
#  'krups',
#  'usando',
#  'filtros',
#  'papel',
#  'filtro',
#  'permamente',
#  'mención',
#  'característica',
#  'clave',
#  'dial',
#  'fecha',
#  'tapa',
#  'recordarle',
#  'debe',
#  'reemplazar',
#  'válvula',
#  'revisé',
#  'fecha',
#  'caducidad',
#  'cuestión',
#  'nueno',
#  'uso',
#  'propio',
#  'llego',
#  'perfectas',
#  'condiciones',
#  'paqueterías',
#  'llega',
#  'roto',
#  'maltratado',
#  'pedí',
#  'descafeinado',
#  'llegó',
#  'normal',
#  'indican',
#  'puedo',
#  'devolverlo',
#  'llegó',
#  'bien',
#  'pedido',
#  'primera',
#  'vez',
#  'pasa',
#  'verdad',
#  'esperaba',
#  'costo',
#  'pense',
#  'cafetera',
#  'sabor',
#  'cafe',
#  'soluble',
#  'costo',
#  'vale',
#  'pena',
#  'perfecto',
#  'podemos',
#  'recibir',
#  'sobres',
#  'pensando',
#  'si',
#  'ir',
#  'procuraduría',
#  'consumidor',
#  'salubridad',
#  'raro',
#  'sistema',
#  'filtros',
#  'funciona',
#  'adecuadamente',
#  'parecer',
#  'pueden',
#  'reemplazar',
#  'filtros',
#  'ordinarios',
#  'bolsas',
#  'café',
#  'estándar',
#  'articulo',
#  'porqueria',
#  'verdad',
#  'permiten',
#  'amazon',
#  'venda',
#  'productos',
#  'calidad',
#  'práctico',
#  'venderlo',
#  'moler',
#  'además',
#  'devoluciones',
#  'ello',
#  'voy',
#  'perder',
#  'dinero',
#  'many',
#  'quejado',
#  'café',
#  'rancio',
#  'falta',
#  'vacío',
#  'abrir',
#  'lata',
#  'compré',
#  'flamingo',
#  'descafeinado',
#  'abuela',
#  'prohibieron',
#  'cafeína',
#  'decepcionó',
#  'voy',
#  'tirar',
#  'puede',
#  'animé',
#  'comprarlo',
#  'comentarios',
#  'aquí',
#  'amazon',
#  'embargo',
#  'experiencia',
#  'comprador',
#  'buen',
#  'sabor',
#  'da',
#  'aroma',
#  'sabor',
#  'café',
#  'retrogusto',
#  'si',
#  'viejo',
#  'mal',
#  'empacado',
#  'tirado',
#  'pestaña',
#  'sacarlo',
#  'lata',
#  'pestaña',
#  'separó',
#  'tapa',
#  'dos',
#  'infracciones',
#  'derecha',
#  'palo',
#  'tamaño',
#  'pequeño',
#  'tiempo',
#  'caducidad',
#  'uso',
#  'lugar',
#  'comprados',
#  'tienda',
#  'cápsulas',
#  'café',
#  'ahorrar',
#  'dinero',
#  'comprar',
#  'éstos',
#  'bulto',
#  'coffeehit',
#  'proporciona',
#  'actualidad',
#  'válvulas',
#  'delivered',
#  'única',
#  'pequeña',
#  'pega',
#  'viene',
#  'lata',
#  'cosa',
#  'buena',
#  'alguien',
#  'casa',
#  'hora',
#  'parto',
#  'posible',
#  'poner',
#  'través',
#  'buzón',
#  'ocurre',
#  'café',
#  'comparando',
#  'tienda',
#  'vs',
#  'amazon',
#  'sobrecosto',
#  'luego',
#  'amargo',
#  'sabor',
#  'quemado',
#  'hacen',
#  'disimular',
#  'impurezas',
#  'grano',
#  'intentare',
#  'hacer',
#  'prefería',
#  'nescafé',
#  'oro',
#  'mezcla',
#  'arábica',
#  'robusta',
#  'beans',
#  'store',
#  'esperaba',
#  'volvería',
#  'comprar',
#  'presentación',
#  'elemento',
#  'actualmente',
#  'viene',
#  'seis',
#  'válvulas',
#  'reemplazo',
#  'cuestan',
#  'reemplazar',
#  'través',
#  'amazon',
#  'mejores',
#  'granos',
#  'comprado',
#  'tomarían',
#  'ninguna',
#  'ahora',
#  'mandan',
#  'descafeinado',
#  'mandan',
#  'normal',
#  'contento',
#  'ponerle',
#  'veces',
#  'normalmente',
#  'ponemos',
#  'aun',
#  'asi',
#  'sabor',
#  'bueno',
#  'gran',
#  'cosa',
#  'queda',
#  'quiero',
#  'recalcar',
#  'llevo',
#  'años',
#  'bebiendo',
#  'café',
#  'pues',
#  'si',
#  'gusta',
#  'aguadón',
#  'pues',
#  'van',
#  'percaté',
#  'venía',
#  'grano',
#  'hecho',
#  'pidió',
#  'idea',
#  'último',
#  'momento',
#  'productos',
#  'recomienda',
#  'después',
#  'añadí',
#  'valhalla',
#  'java',
#  'café',
#  'molido',
#  'death',
#  'wish',
#  'coffee',
#  'company',
#  'usda',
#  'certified',
#  'organic',
#  'trade',
#  'fair',
#  'onza',
#  'bolsa',
#  'cesta',
#  'narcolepsia',
#  'constantemente',
#  'quedando',
#  'dormido',
#  'venta',
#  'producto',
#  'comestible',
#  'espuria',
#  'delito',
#  'grave',
#  'puede',
#  'afectar',
#  'negativamente',
#  'salud',
#  'what',
#  'date',
#  'were',
#  'you',
#  'born',
#  'submitadobe',
#  'flash',
#  'player',
#  'is',
#  'required',
#  'to',
#  'watch',
#  'this',
#  'video',
#  'pesado',
#  'báscula',
#  'extremadamente',
#  'decepcionado',
#  'compra',
#  'cualquier',
#  'lavazzo',
#  'productos',
#  'futuro',
#  'comentarios',
#  'mismo',
#  'problema',
#  'posible',
#  'corrijan',
#  'error',
#  'diferencia',
#  'consumidores',
#  'caso',
#  'café',
#  'llegó',
#  'fecha',
#  'caducidad',
#  'meses',
#  'expirara',
#  'obviamente',
#  'acabó',
#  'meses',
#  'producto',
#  'llegó',
#  'roto',
#  'venir',
#  'bien',
#  'sólo',
#  'creo',
#  'alguna',
#  'tan',
#  'bueno',
#  'cuanto',
#  'calidad',
#  'lavazza',
#  'rossa',
#  'tratamos',
#  'caso',
#  'puede',
#  'conseguir',
#  'alguna',
#  'razón',
#  'éste',
#  'compra',
#  'caja',
#  'medios',
#  'vainas',
#  'comprar',
#  'pequeñas',
#  'cajas',
#  'todas',
#  'semanas',
#  'vez',
#  'abierto',
#  'pueden',
#  'secarse',
#  'si',
#  'almacenan',
#  'bien',
#  'cuidado',
#  'compre',
#  'decía',
#  'an',
#  'pague',
#  'esperando',
#  'llegarán',
#  'así',
#  'necesitan',
#  'específicar',
#  'mejor',
#  'ofertas',
#  'funcionan',
#  'artículo',
#  'bien',
#  'pedi',
#  'abril',
#  'llego',
#  'fecha',
#  'caducidad',
#  'marzo',
#  'osea',
#  'caduco',
#  'pedí',
#  'probarlo',
#  'gusto',
#  'deseo',
#  'pronto',
#  'vendan',
#  'ediciones',
#  'taster',
#  'choice',
#  'recomiendo',
#  'café',
#  'desgastante',
#  'estresante',
#  'comprado',
#  'juan',
#  'valdez',
#  'directamente',
#  'así',
#  'amazon',
#  'depende',
#  'si',
#  'jv',
#  'venta',
#  'gastos',
#  'envío',
#  'alguna',
#  'razón',
#  'gran',
#  'cantidad',
#  'marcas',
#  'estadounidenses',
#  'atascan',
#  'tolva',
#  'gustó',
#  'producto',
#  'sabe',
#  'café',
#  'viejo',
#  'cuerpo',
#  'sabor',
#  'usar',
#  'producto',
#  'taza',
#  'sentir',
#  'mejor',
#  'sabor',
#  'horrible',
#  'orgánico',
#  'recomendaría',
#  'timo',
#  'seguro',
#  'útil',
#  'discos',
#  'si',
#  'haces',
#  'tazas',
#  'café',
#  'día',
#  'muele',
#  'probablemente',
#  'cada',
#  'semanas',
#  'necesitará',
#  'discos',
#  'si',
#  'cumple',
#  'indica',
#  'granos',
#  'tuestan',
#  'claramente',
#  'diferente',
#  'experiencia',
#  'desagradable',
#  'si',
#  'esperando',
#  'medio',
#  'termina',
#  'medley',
#  'now',
#  'creo',
#  'amazon',
#  'grande',
#  'diciendo',
#  'realidad',
#  'tostado',
#  'medio',
#  'remitente',
#  'excelente',
#  'pongo',
#  'estrellas',
#  'vendedor',
#  'amazon',
#  'además',
#  'supongo',
#  'contenedor',
#  'hermético',
#  'vez',
#  'filtro',
#  'degradado',
#  'tercera',
#  'botella',
#  'simplemente',
#  'parece',
#  'puede',
#  'conformarse',
#  'cualquier',
#  'café',
#  'instantáneo',
#  'inmediatamente',
#  'después',
#  'apertura',
#  'bolsa',
#  'olía',
#  'exceso',
#  'tostado',
#  'sabía',
#  'iba',
#  'ser',
#  'amargo',
#  'áspero',
#  'pedido',
#  'tostado',
#  'medio',
#  'dieron',
#  'asado',
#  'ligero',
#  'decepcionado',
#  'asado',
#  'luz',
#  'buena',
#  'general',
#  'segunda',
#  'vez',
#  'sale',
#  'producto',
#  'equivocado',
#  'pedí',
#  'cápsulas',
#  'etiqueta',
#  'verde',
#  'descafeinado',
#  'illy',
#  'terminado',
#  'alguna',
#  'manera',
#  'tres',
#  'pequeñas',
#  'latas',
#  'café',
#  'descafeinado',
#  'planta',
#  'agua',
#  'proceso',
#  'etiqueta',
#  'azul',
#  'cápsulas',
#  'conclusión',
#  'comprando',
#  'frecuencia',
#  'opción',
#  'oaxaca',
#  'supuesto',
#  'gusto',
#  'prima',
#  'peor',
#  'además',
#  'dicho',
#  'café',
#  'cultivos',
#  'alta',
#  'penetración',
#  'pesticidas',
#  'bolsa',
#  'gramos',
#  'triste',
#  'decepción',
#  'así',
#  'mismo',
#  'resulta',
#  'caro',
#  'producto',
#  'ser',
#  'mas',
#  'especifico',
#  'imágenes',
#  'favor',
#  'marca',
#  'si',
#  'sola',
#  'mas',
#  'reconocidas',
#  'cuanto',
#  'cafe',
#  'refiere',
#  'probablemente',
#  'voy',
#  'volver',
#  'surtir',
#  'meses',
#  'menos',
#  'adderall',
#  'ayuda',
#  'vyvanse',
#  'ayuda',
#  'liso',
#  'regusto',
#  'precio',
#  'tampoco',
#  'mal',
#  'encontré',
#  'alrededor',
#  'mxn',
#  'dólares',
#  'parece',
#  'oferta',
#  'quería',
#  'hacer',
#  'devolución',
#  'pudo',
#  'buen',
#  'recomiendo',
#  'vencer',
#  'davidoff',
#  'polvo',
#  'café',
#  'encanta',
#  'mezcla',
#  'arábica',
#  'robusta',
#  'intenso',
#  'sabor',
#  'rossa',
#  'mismas',
#  'notas',
#  'chocolate',
#  'sabor',
#  'amargo',
#  'quemado',
#  'arrepiento',
#  'venía',
#  'abierto',
#  'nota',
#  'quisieron',
#  'invertir',
#  'mejor',
#  'empaque',
#  'recomendado',
#  'usted',
#  'puede',
#  'comprar',
#  'ladrillo',
#  'walmart',
#  'decepcionante',
#  'diferente',
#  'grado',
#  'molienda',
#  'cuenta',
#  'tantas',
#  'críticas',
#  'quejándose',
#  'parece',
#  'vendedor',
#  'quiere',
#  'responder',
#  'solucionarlo',
#  'pedido',
#  'incluye',
#  'frascos',
#  'ninguno',
#  'venia',
#  'protegido',
#  'plastico',
#  'carton',
#  'errores',
#  'hijo',
#  'corta',
#  'sacarlo',
#  'empaque',
#  'venia',
#  'cayeron',
#  'pedazos',
#  'vidrio',
#  'todas',
#  'partes',
#  'whereas',
#  'davidoff',
#  'frijoles',
#  'puramente',
#  'arábica',
#  'viene',
#  'filtros',
#  'repuesto',
#  'información',
#  'completa',
#  'dentro',
#  'caja',
#  'sabor',
#  'ninguna',
#  'manera',
#  'puedo',
#  'ver',
#  'pagar',
#  'pésimo',
#  'nunca',
#  'sido',
#  'fan',
#  'sabor',
#  'menos',
#  'da',
#  'kick',
#  'cafeína',
#  'iniciar',
#  'día',
#  'menos',
#  'peso',
#  'razón',
#  'devolveré',
#  'producto',
#  'ambos',
#  'frascos',
#  'presentan',
#  'diferente',
#  'tonalidad',
#  'producto',
#  'café',
#  'soluble',
#  'lado',
#  'ambos',
#  'frascos',
#  'caducados',
#  'presentan',
#  'mismo',
#  'lote',
#  'pdc',
#  'mezcla',
#  'emir',
#  'mezcla',
#  'casa',
#  'jarocho',
#  'fuerte',
#  'puede',
#  'superar',
#  'macizo',
#  'comprar',
#  'cualquier',
#  'lugar',
#  'sólo',
#  'puedo',
#  'llenar',
#  'keurig',
#  'vaina',
#  'medio',
#  'camino',
#  'obstruye',
#  'cafetera',
#  'méxico',
#  'buenos',
#  'cafés',
#  'desafortunadamente',
#  'técnica',
#  'tostión',
#  'pobre',
#  'optado',
#  'lata',
#  'pequeña',
#  'grande',
#  'caro',
#  'sé',
#  'si',
#  'pierde',
#  'sabor',
#  'tiempo',
#  'cuadro',
#  'grande',
#  'quería',
#  'café',
#  'amazon',
#  'dijo',
#  'posible',
#  'volver',
#  'artículo',
#  'méxico',
#  'enganchado',
#  'entonces',
#  'arriesgué',
#  'perdí',
#  'pesos',
#  'recomendaría',
#  'comprarlo',
#  'caso',
#  'llegó',
#  'roto',
#  'llegué',
#  'solución',
#  'rápida',
#  'amazon',
#  'siempre',
#  'garantía',
#  'comprar',
#  'reembolso',
#  'conseguido',
#  'doy',
#  'tres',
#  'estrellas',
#  'creo',
#  'indica',
#  'judías',
#  'antiguas',
#  'incrementa',
#  'aspecto',
#  'seco',
#  'granos',
#  'dentro',
#  'cuanto',
#  'precio',
#  'velocidad',
#  'entrega',
#  'estuvoas',
#  'seguro',
#  'si',
#  'sólo',
#  'mal',
#  'lote',
#  'compraría',
#  'nuevo',
#  'van',
#  'manera',
#  'mamá',
#  'norte',
#  'tundra',
#  'congelada',
#  'ama',
#  'ojalá',
#  'cuiden',
#  'aspecto',
#  'aunque',
#  'caducidad',
#  'verdad',
#  'si',
#  'mes',
#  'haber',
#  'sido',
#  'tostado',
#  'vale',
#  'pena',
#  'comprar',
#  'si',
#  'necesita',
#  'granos',
#  'absolutamente',
#  'puede',
#  'conseguir',
#  'ningún',
#  'lugar',
#  'veo',
#  'fecha',
#  'empaquetamiento',
#  'parecer',
#  'hace',
#  'café',
#  'perdió',
#  'propiedades',
#  'the',
#  'única',
#  'cosa',
#  'gusta',
#  'illy',
#  'dan',
#  'dos',
#  'años',
#  'café',
#  'punto',
#  'expirar',
#  'estándares',
#  'seis',
#  'meses',
#  'empresas',
#  'dan',
#  'empujar',
#  'bit',
#  'podría',
#  'añadir',
#  'café',
#  'café',
#  'othermexican',
#  'timefavorites',
#  'recibes',
#  'calidad',
#  'pagaste',
#  'grano',
#  'pequeño',
#  'sabor',
#  'entusiasta',
#  'café',
#  'hago',
#  'espressos',
#  'técnica',
#  'prensado',
#  'manual',
#  'primera',
#  'vez',
#  'llego',
#  'excelentemente',
#  'empacado',
#  'frasco',
#  'sellado',
#  'última',
#  'ocasión',
#  'frasco',
#  'bien',
#  'empaquetado',
#  'embargo',
#  'frasco',
#  'sello',
#  'fábrica',
#  ...]

# %%
oraciones_lista[1]
# Out:
# ser
# mas
# especifico
# imágenes
# favor
# marca
# si
# sola
# mas
# reconocidas
# cuanto
# cafe
# refiere
# probablemente
# voy
# volver
# surtir
# meses
# menos
# adderall
# ayuda
# vyvanse
# ayuda
# liso
# regusto
# precio

# %% [markdown]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
from gensim.models import Word2Vec

# %% [markdown]
# # Modelo de W2V

# %%
frases=[["café", "es", "bueno"],
        ["café", "con", "sabor"],
        ["café", "con", "aroma"],
        ["aroma", "es", "dulce"],
        ["café", "con", "sabor"],
        ["dulce", "y", "amargo"],
        ["café", "con", "sabor"],
        ["saborear","el","café"],
        ["saborear","café"],
        ["aroma","del","café"],
        ["aroma","café","cuerpo"],
        ["tener","cuerpo"],
        ["el","sabor","es","amargo"],
        ["de","amargo","sabor"],
        ["el","sabor","es","amargo"],
        ["el","no","es" ,"sabor","amargo"]
       ]
modelo = Word2Vec(frases,min_count=1)

# %%
words = list(modelo.wv.vocab)
print(words)
# Out:
# ['café', 'es', 'bueno', 'con', 'sabor', 'aroma', 'dulce', 'y', 'amargo', 'saborear', 'el', 'del', 'cuerpo', 'tener', 'de', 'no']

# %%
modelo.most_similar('café')
# Out:
# C:\Users\Armando\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [('saborear', 0.1979386955499649),
#  ('y', 0.14353571832180023),
#  ('del', 0.13145312666893005),
#  ('sabor', 0.07672049850225449),
#  ('no', 0.06800684332847595),
#  ('de', 0.05438022315502167),
#  ('es', 0.05159362778067589),
#  ('el', 0.03188473358750343),
#  ('aroma', 0.016630426049232483),
#  ('dulce', -0.00908823311328888)]

# %% [markdown]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
from sklearn.decomposition import PCA #Para Graficar PCA functions

# %%
palabras333=['café','bueno','sabor','y','aroma', 'dulce','amargo', 'saborear','del', 'cuerpo', 'tener']
modelo_aplicado=modelo[palabras333]
# Out:
# C:\Users\Armando\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app

# %%
# Transformar modelo 2d
X = modelo_aplicado
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
import matplotlib.pyplot as plt #importamos para graficos

# %%
# create a plot of the projection
fig, ax = plt.subplots()
fig.set_size_inches(8, 7)
ax.plot(result[:, 0], result[:, 1], 'x')
ax.set_title('Encabezado')


words = list(palabras333)
for i, word in enumerate(words):
    plt.annotate(word, xy=(result[i, 0],result[i, 1]))

plt.show()
