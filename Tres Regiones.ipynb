# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import summary_table
from sklearn.preprocessing import PolynomialFeatures
from statsmodels.stats.outliers_influence import summary_table

# %%
Base_de_Datos= pd.read_excel('region.xlsx')
Datos=pd.DataFrame(Base_de_Datos)
Datos.head(7)
# Out:
#    Obs  Salario  Gasto                   Region
# 0    1    19583   3346  Noroeste y Norte Centro
# 1    2    20263   3114  Noroeste y Norte Centro
# 2    3    20325   3554  Noroeste y Norte Centro
# 3    4    26800   4642  Noroeste y Norte Centro
# 4    5    29470   4669  Noroeste y Norte Centro
# 5    6    26610   4888  Noroeste y Norte Centro
# 6    7    30678   5710  Noroeste y Norte Centro

# %%
#g = sns.lmplot(x="Gasto", y="Salario", hue="Region",data=Datos,markers=['x','o','*'],palette="Set1")
#sns.lmplot(x="Gasto", y="Salario", col="Region",data=Datos, hue="Region")
g = sns.lmplot(x="Gasto", y="Salario", hue="Region",data=Datos,markers=['x','o','*'],palette="Set1",size=9)

# %%
#convertir en dummy
df_x=Datos.drop(['Obs','Salario'], axis=1)
df_x=pd.get_dummies(df_x)

# %%
df_x.head(4)
# Out:
#    Gasto  Region_Noroeste y Norte Centro  Region_Oeste  Region_Sur
# 0   3346                               1             0           0
# 1   3114                               1             0           0
# 2   3554                               1             0           0
# 3   4642                               1             0           0

# %%
x=df_x.values
y=Datos["Salario"].values

# %%
model = ols("Salario~Gasto+Region", Datos).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Salario   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.705
# Method:                 Least Squares   F-statistic:                     40.82
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):           3.87e-13
# Time:                        03:07:03   Log-Likelihood:                -464.39
# No. Observations:                  51   AIC:                             936.8
# Df Residuals:                      47   BIC:                             944.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         1.16e+04   1334.367      8.690      0.000    8911.199    1.43e+04
# ...
